# %%
from models import SentenceEmbedders, utils
from models import experiments

# %% [markdown]
# ### Tests

# %%
bert_tests = utils.load_pkl('bert-embeddings/bert_tests_allLayers_maxlen200.pkl')

# %%
mc_experiment = experiments.ExperimentResult(log = ['embeddings_model', 
                                                    'classifier',
                                                    'layers', 
                                                    'pooling', 
                                                    'accuracy', 
                                                    'f1'])
df = experiments.run_inputs_experiments(mc_experiment,
                                        bert_tests,
                                        classifier='CatBoost',
                                        problem_type='multiple-choice',
                                        strategy=['mean', 'max'], 
                                        single_layers=[i for i in range(1, 13)],
                                        layers=[(1, 12), (1, 6), (7, 12), (1, 3), (4, 6), (6, 9), (9, 12)])

# %%
print('index of the best accuracy score: ', df['accuracy'].idxmax())
print('index of the best f1: ', df['f1'].idxmax())
# Out:
# index of the best accuracy score:  23
# index of the best f1:  23

# %%
df
# Out:
#    embeddings_model classifier   layers       pooling  accuracy     f1
# 0   bert-as-service   CatBoost        1  single_layer     0.318  0.318
# 1   bert-as-service   CatBoost        2  single_layer     0.320  0.320
# 2   bert-as-service   CatBoost        3  single_layer     0.338  0.338
# 3   bert-as-service   CatBoost        4  single_layer     0.332  0.332
# 4   bert-as-service   CatBoost        5  single_layer     0.317  0.317
# 5   bert-as-service   CatBoost        6  single_layer     0.322  0.322
# 6   bert-as-service   CatBoost        7  single_layer     0.312  0.311
# 7   bert-as-service   CatBoost        8  single_layer     0.329  0.329
# 8   bert-as-service   CatBoost        9  single_layer     0.329  0.328
# 9   bert-as-service   CatBoost       10  single_layer     0.319  0.319
# 10  bert-as-service   CatBoost       11  single_layer     0.314  0.314
# 11  bert-as-service   CatBoost       12  single_layer     0.318  0.318
# 12  bert-as-service   CatBoost  (1, 12)          mean     0.329  0.330
# 13  bert-as-service   CatBoost   (1, 6)          mean     0.320  0.320
# 14  bert-as-service   CatBoost  (7, 12)          mean     0.334  0.334
# 15  bert-as-service   CatBoost   (1, 3)          mean     0.327  0.326
# 16  bert-as-service   CatBoost   (4, 6)          mean     0.330  0.329
# 17  bert-as-service   CatBoost   (6, 9)          mean     0.334  0.334
# 18  bert-as-service   CatBoost  (9, 12)          mean     0.326  0.326
# 19  bert-as-service   CatBoost  (1, 12)           max     0.323  0.322
# 20  bert-as-service   CatBoost   (1, 6)           max     0.327  0.327
# 21  bert-as-service   CatBoost  (7, 12)           max     0.328  0.328
# 22  bert-as-service   CatBoost   (1, 3)           max     0.340  0.341
# 23  bert-as-service   CatBoost   (4, 6)           max     0.346  0.346
# 24  bert-as-service   CatBoost   (6, 9)           max     0.313  0.313
# 25  bert-as-service   CatBoost  (9, 12)           max     0.334  0.333

# %% [markdown]
# ### News

# %%
bert_news_1 = utils.load_pkl('bert-embeddings/bert_news_LAYERS_1-6_maxlen200.pkl')
bert_news_2 = utils.load_pkl('bert-embeddings/bert_news_LAYERS_7-12_maxlen200.pkl')

# %%
news_experiment = experiments.ExperimentResult(log = ['embeddings_model', 
                                                      'classifier',
                                                      'layers', 
                                                      'pooling', 
                                                      'accuracy', 
                                                      'f1'])
df_news_1 = experiments.run_inputs_experiments(news_experiment,
                                        bert_news_1,
                                        classifier='CatBoost',
                                        problem_type='multiple-choice',
                                        strategy=['mean', 'max'], 
                                        single_layers=[i for i in range(1, 7)],
                                        layers=[(1, 6), (1, 3), (4, 6)])

# %%
news_experiment = experiments.ExperimentResult(log = ['embeddings_model', 
                                                      'classifier',
                                                      'layers', 
                                                      'pooling', 
                                                      'accuracy', 
                                                      'f1'])
df_news_2 = experiments.run_inputs_experiments(news_experiment,
                                        bert_news_2,
                                        classifier='CatBoost',
                                        problem_type='multiple-choice',
                                        strategy=['mean', 'max'], 
                                        single_layers=[i for i in range(1, 7)],
                                        layers=[(1, 6), (1, 3), (4, 6)])

# %%
df_news_2['layers'] = df_news_2['layers'].apply(lambda x: (x[0] + 6, x[1] + 6) if isinstance(x, tuple) else x + 6)

# %%
import pandas as pd
df_news = pd.concat([df_news_1[:6], df_news_2[:6], df_news_1[6:], df_news_2[6:]])
df_news.reset_index(inplace=True)

# %%
print('index of the best accuracy score: ', df_news['accuracy'].idxmax())
print('index of the best f1: ', df_news['f1'].idxmax())
# Out:
# index of the best accuracy score:  18
# index of the best f1:  18

# %%
df_news
# Out:
#     index embeddings_model classifier    layers       pooling  accuracy     f1
# 0       0  bert-as-service   CatBoost         1  single_layer     0.414  0.414
# 1       1  bert-as-service   CatBoost         2  single_layer     0.447  0.447
# 2       2  bert-as-service   CatBoost         3  single_layer     0.465  0.465
# 3       3  bert-as-service   CatBoost         4  single_layer     0.470  0.470
# 4       4  bert-as-service   CatBoost         5  single_layer     0.498  0.498
# 5       5  bert-as-service   CatBoost         6  single_layer     0.485  0.485
# 6       0  bert-as-service   CatBoost         7  single_layer     0.467  0.467
# 7       1  bert-as-service   CatBoost         8  single_layer     0.489  0.489
# 8       2  bert-as-service   CatBoost         9  single_layer     0.461  0.461
# 9       3  bert-as-service   CatBoost        10  single_layer     0.482  0.482
# 10      4  bert-as-service   CatBoost        11  single_layer     0.511  0.510
# 11      5  bert-as-service   CatBoost        12  single_layer     0.497  0.497
# 12      6  bert-as-service   CatBoost    (1, 6)          mean     0.484  0.484
# 13      7  bert-as-service   CatBoost    (1, 3)          mean     0.448  0.448
# 14      8  bert-as-service   CatBoost    (4, 6)          mean     0.499  0.499
# 15      9  bert-as-service   CatBoost    (1, 6)           max     0.470  0.470
# 16     10  bert-as-service   CatBoost    (1, 3)           max     0.446  0.446
# 17     11  bert-as-service   CatBoost    (4, 6)           max     0.492  0.492
# 18      6  bert-as-service   CatBoost   (7, 12)          mean     0.514  0.514
# 19      7  bert-as-service   CatBoost    (7, 9)          mean     0.493  0.493
# 20      8  bert-as-service   CatBoost  (10, 12)          mean     0.509  0.509
# 21      9  bert-as-service   CatBoost   (7, 12)           max     0.481  0.481
# 22     10  bert-as-service   CatBoost    (7, 9)           max     0.473  0.473
# 23     11  bert-as-service   CatBoost  (10, 12)           max     0.501  0.501

# %% [markdown]
# ### Paraphrase

# %%
bert_paraphrase = utils.load_pkl('bert-embeddings/bert_paraphrase_allLayers_maxlen200.pkl')

# %%
paraphrase_experiment = experiments.ExperimentResult(log = ['embeddings_model', 
                                                            'classifier',
                                                            'layers', 
                                                            'pooling', 
                                                            'accuracy', 
                                                            'f1'])
df = experiments.run_inputs_experiments(paraphrase_experiment,
                                        bert_paraphrase,
                                        classifier='CatBoost',
                                        problem_type='paraphrase',
                                        strategy=['mean', 'max'], 
                                        single_layers=[i for i in range(1, 13)],
                                        layers=[(1, 12), (1, 6), (7, 12), (1, 3), (4, 6), (6, 9), (9, 12)])

# %%
print('index of the best accuracy score: ', df['accuracy'].idxmax())
print('index of the best f1: ', df['f1'].idxmax())
# Out:
# index of the best accuracy score:  24
# index of the best f1:  2

# %%
df
# Out:
#    embeddings_model classifier   layers       pooling  accuracy     f1
# 0   bert-as-service   CatBoost        1  single_layer     0.762  0.708
# 1   bert-as-service   CatBoost        2  single_layer     0.764  0.711
# 2   bert-as-service   CatBoost        3  single_layer     0.776  0.732
# 3   bert-as-service   CatBoost        4  single_layer     0.767  0.717
# 4   bert-as-service   CatBoost        5  single_layer     0.768  0.725
# 5   bert-as-service   CatBoost        6  single_layer     0.762  0.716
# 6   bert-as-service   CatBoost        7  single_layer     0.776  0.730
# 7   bert-as-service   CatBoost        8  single_layer     0.752  0.698
# 8   bert-as-service   CatBoost        9  single_layer     0.765  0.712
# 9   bert-as-service   CatBoost       10  single_layer     0.749  0.696
# 10  bert-as-service   CatBoost       11  single_layer     0.763  0.715
# 11  bert-as-service   CatBoost       12  single_layer     0.758  0.706
# 12  bert-as-service   CatBoost  (1, 12)          mean     0.764  0.718
# 13  bert-as-service   CatBoost   (1, 6)          mean     0.773  0.726
# 14  bert-as-service   CatBoost  (7, 12)          mean     0.765  0.718
# 15  bert-as-service   CatBoost   (1, 3)          mean     0.762  0.709
# 16  bert-as-service   CatBoost   (4, 6)          mean     0.756  0.706
# 17  bert-as-service   CatBoost   (6, 9)          mean     0.753  0.698
# 18  bert-as-service   CatBoost  (9, 12)          mean     0.756  0.708
# 19  bert-as-service   CatBoost  (1, 12)           max     0.757  0.702
# 20  bert-as-service   CatBoost   (1, 6)           max     0.753  0.698
# 21  bert-as-service   CatBoost  (7, 12)           max     0.766  0.716
# 22  bert-as-service   CatBoost   (1, 3)           max     0.767  0.716
# 23  bert-as-service   CatBoost   (4, 6)           max     0.749  0.694
# 24  bert-as-service   CatBoost   (6, 9)           max     0.778  0.732
# 25  bert-as-service   CatBoost  (9, 12)           max     0.765  0.718
